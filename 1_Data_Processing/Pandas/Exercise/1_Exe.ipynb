# %% [markdown]
# # Exercise 1

# %%
import pandas as pd 
import numpy as np

df = pd.read_csv("C:\\Users\\maham\\Videos\\Gen AI Practice\\Data\\Flavors.csv")

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
df.head(5)
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1            Chocolate   Chocolate   Yes            8.8             7.6
# 2              Vanilla     Vanilla    No            4.7             5.0
# 3         Cookie Dough     Vanilla   Yes            6.9             6.5
# 4           Rocky Road   Chocolate   Yes            8.2             7.0
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
df.shape
# Out:
# (9, 6)

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 6

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df.columns
# Out:
# Index(['Flavor', 'Base Flavor', 'Liked', 'Flavor Rating', 'Texture Rating',
#        'Total Rating'],
#       dtype='object')

# %% [markdown]
# ### Step 8. What is the name of 5th column?

# %%
df.columns[4]
# Out:
# 'Texture Rating'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 5th column?

# %%
df['Texture Rating'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Flavor             object
# Base Flavor        object
# Liked              object
# Flavor Rating     float64
# Texture Rating    float64
# Total Rating      float64
# dtype: object

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 4th observation?

# %%
df.values[3][1]
# Out:
# 'Vanilla'
