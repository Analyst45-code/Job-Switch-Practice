# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Reading Data

# %%
data = pd.read_csv('../Datasets/Flavors.csv')
data2 = pd.read_csv('../Datasets/Flavors.csv', sep=',', header = None, names=['1','2','3','4'])
data2.head(2)
# Out:
#                                      1              2               3  \
# Flavor              Base Flavor  Liked  Flavor Rating  Texture Rating
# Mint Chocolate Chip Vanilla        Yes             10               8
#
#                                             4
# Flavor              Base Flavor  Total Rating
# Mint Chocolate Chip Vanilla                18

# %%
text_file = pd.read_csv('../Datasets/countries of the world.csv')

# %%
json_file = pd.read_json('../Datasets/json_sample.json')
json_file.head(3)
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
excel_file = pd.read_excel('../Datasets/Athletes.xlsx', sheet_name='Details')
excel_file.head(2)
# Out:
#               Name     NOC           Discipline
# 0  AALERUD Katrine  Norway         Cycling Road
# 1      ABAD Nestor   Spain  Artistic Gymnastics

# %% [markdown]
# 1. Head - return top rows from data
# 2. tail - return last rows from data

# %%
data.head(3)
data.tail(3)
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 6          12.5
# 7           8.8
# 8          15.3

# %%
data.head(-2)       # Ignore Last 2 Rows
data.tail(-2)       # Ignore first 2 Rows
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %% [markdown]
# ### Information Functions
# 1. info - return detailed information about data like index column name non null count as dtype
# 2. Desc - return statistics information about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Flavor          9 non-null      object
#  1   Base Flavor     9 non-null      object
#  2   Liked           9 non-null      object
#  3   Flavor Rating   9 non-null      float64
#  4   Texture Rating  9 non-null      float64
#  5   Total Rating    9 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 564.0+ bytes

# %%
# Describe function provide descriptive statistics about the data
data.describe()
# Out:
#        Flavor Rating  Texture Rating  Total Rating
# count         9.0000        9.000000      9.000000
# mean          6.6000        6.177778     12.800000
# std           2.5387        1.478832      4.030509
# min           2.3000        3.400000      5.700000
# 25%           4.7000        5.000000      9.700000
# 50%           6.9000        6.500000     13.400000
# 75%           8.2000        7.100000     15.300000
# max          10.0000        8.000000     18.000000

# %%
# Shape give rows and columns count of data
data.shape
# Out:
# (9, 6)

# %%
# Give total size of data
data.size
# Out:
# 54

# %%
data.items
# Out:
# <bound method DataFrame.items of                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3  >

# %%
data.dtypes
# Out:
# Flavor             object
# Base Flavor        object
# Liked              object
# Flavor Rating     float64
# Texture Rating    float64
# Total Rating      float64
# dtype: object

# %% [markdown]
# #### Selecting Columns

# %%
data['Base Flavor']
# Out:
# 0      Vanilla
# 1    Chocolate
# 2      Vanilla
# 3      Vanilla
# 4    Chocolate
# 5      Vanilla
# 6      Vanilla
# 7      Vanilla
# 8    Chocolate
# Name: Base Flavor, dtype: object

# %%
# Selecting Multiple columns
data[['Base Flavor', 'Flavor']]
# Out:
#   Base Flavor                  Flavor
# 0     Vanilla     Mint Chocolate Chip
# 1   Chocolate               Chocolate
# 2     Vanilla                 Vanilla
# 3     Vanilla            Cookie Dough
# 4   Chocolate              Rocky Road
# 5     Vanilla               Pistachio
# 6     Vanilla             Cake Batter
# 7     Vanilla              Neapolitan
# 8   Chocolate  Chocolte Fudge Brownie
